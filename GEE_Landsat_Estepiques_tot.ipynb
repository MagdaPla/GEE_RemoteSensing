# %% [markdown]
# <a href="https://colab.research.google.com/github/MagdaPla/GEE_RemoteSensing/blob/main/GEE_Landsat_Estepiques_tot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# muntar el directori de drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Run the following cell to import the API into your session.
import ee
# import other packs
import os 
import datetime 
from datetime import datetime as dt
import sys
from collections import namedtuple

# %%
#Create structure to hold setting parameters
set_par_est = namedtuple("set_par_est", "sel_col bands p_out offset QA QA_bands Indices scale mult")

# %% [markdown]
# Ara introduïm algunes funcions per a enmascarar núvols de Landsat, per a tractar les dates, etc.

# %%
#https://gis.stackexchange.com/questions/274048/apply-cloud-mask-to-landsat-imagery-in-google-earth-engine-python-api
#A function to mask out cloudy pixels.
def getQABits(image, start, end, mascara):
    # Compute the bits we need to extract.
    pattern = 0
    for i in range(start,end-1):
        pattern += 2**i
    # Return a single band image of the extracted QA bits, giving the     band a new name.
    return image.select([0], [mascara]).bitwiseAnd(pattern).rightShift(start)


#https://gis.stackexchange.com/questions/274048/apply-cloud-mask-to-landsat-imagery-in-google-earth-engine-python-api
def maskQuality(image):
    # Select the QA band.
    QA = image.select('pixel_qa')
    # Get the internal_cloud_algorithm_flag bit.
    sombra = getQABits(QA,3,3,'cloud_shadow')
    nubes = getQABits(QA,5,5,'cloud')
    #  var cloud_confidence = getQABits(QA,6,7,  'cloud_confidence')
    cirrus_detected = getQABits(QA,9,9,'cirrus_detected')
    snow_detected = getQABits(QA,4,4,'snow_detected')
    #var cirrus_detected2 = getQABits(QA,8,8,  'cirrus_detected2')
    #Return an image masking out cloudy areas.
    return image.updateMask(sombra.eq(0)).updateMask(nubes.eq(0).updateMask(cirrus_detected.eq(0))).updateMask(snow_detected.eq(0))

# %%
#This procedure computes the number of processing periods depending on a temporal extent and a time interval given
#If the processing periods are not an interger number, meaning an inrregural time series, then the last processing period 
#will become longer including more dates, thus turning the time series into a regular time series
#It returns a string array with all the processing periods

def ComputeProcessingPeriods(time, time_int):

    #date conversion
    d_start=datetime.datetime.strptime(str(time[0]), '%Y-%m-%d')
    d_end=datetime.datetime.strptime(str(time[1]), '%Y-%m-%d')
    
    #total number of days to be processed
    n_days=(d_end-d_start).days+1
    print('Number of days to be processed: '+str(n_days))
    
    #number of processing periods
    print('Number of processing periods: '+str(n_days/time_int))

    #array storing data    
    proc_per=[]

    #Make sure we have regular processing periods.
    #If not assign the remaining days to the last period
    if (n_days%time_int == 0): #In this case the time series is regular
            
        print('Time series is regular: total number of processing periods= '+str(n_days/time_int))
        
        n_pp=int(n_days/time_int)
        
        for i in range(n_pp):

            #set timedelta
            td=time_int*(i+1)-1
    
            date_s=str(d_start+datetime.timedelta(days=time_int*(i))).split(' ')
            date_e=str(d_start+datetime.timedelta(days=time_int*(i+1))).split(' ')
            
            proc_per.append([date_s[0],date_e[0]])
        
    else: #Time series not regular
            
        reg=0   

  
    return proc_per

# %% [markdown]
# A continuació definim la col·lecció de dades amb les que volem treballar, aquest codi està preparat per a diferents productes de Modis i Landsat

# %%
def CollectionSelectionPar(option):
    
    if option ==1: #Collection NDVI 500 m
        
        #product selection
        sel_col='MODIS/MOD09GA_006_NDVI'
        #bands to be processed
        bands = ['NDVI']
        #Google drve output folder
        p_out='UIB-Imatges-MOD09GA-006-NDVI'
        #Image offset
        offset=''


    elif option ==2: #Collection EVI 500 m

        sel_col='UIB-Imatges-MOD09GA-006-EVI'
        bands = ['EVI']
        p_out='UIB-Imatges-MOD09GA_006_EVI'
        #Image offset
        offset=''

    elif option ==3: #Collection surface reflectance 250 m

        sel_col='MODIS/006/MOD09GQ'
        bands = ['sur_refl_b01', 'sur_refl_b02']
        #Â¡p_out='UIB-Imatges-MOD09GQ'
        p_out='UIB-Imatges-MOD09GQ'
        #Image offset
        offset=10000
        #Select MODIS product where QA bands is and the QA bands to be processed from the 500m product
        QA='MODIS/006/MOD09GA'
        QA_bands = ['state_1km', 'QC_500m']
        Indices=['NDVI','EVI2']
        scale=250
        mult=[]
        
    elif option ==4: #Collection surface reflectance 500 m

        sel_col='MODIS/006/MOD09GA'
        bands = ['sur_refl_b01', 'sur_refl_b02','sur_refl_b03','sur_refl_b04','sur_refl_b05','sur_refl_b06','sur_refl_b07'] 
        #Â¡p_out='UIB-Imatges-MOD09GQ'
        p_out='UIB-Imatges-MOD09GA'
        #Image offset
        offset=10000
        #Select MODIS product where QA bands is and the QA bands to be processed from the 500m product
        QA='MODIS/006/MOD09GA'
        QA_bands = ['state_1km', 'QC_500m']
        Indices=['NDVI','EVI2']
        scale=500
        mult=[]

    elif option ==5: #Collection Terra land surface temperature 1000 m

        sel_col='MODIS/006/MOD11A1'
        bands = ['LST_Day_1km', 'Day_view_time','Day_view_angle','LST_Night_1km','Night_view_time','Night_view_angle','Emis_31','Emis_32'] 
        p_out='UIB-Imatges-MOD11A1'
        #Image offset for LST, view time and emissivity
        mult=[0.02,0.1,1,0.002,0.0005]
        offset=[0,0,-65,0.49,0]
        #Select MODIS product where QA bands is and the QA bands to be processed from the 500m product
        QA='MODIS/006/MOD11A1'
        QA_bands = ['QC_Day', 'QC_Night']
        Indices=[]
        scale=1000

    elif option ==6: #Collection Aqua land surface temperature 1000 m

        sel_col='MODIS/006/MYD11A1'
        bands = ['LST_Day_1km', 'Day_view_time','Day_view_angle','LST_Night_1km','Night_view_time','Night_view_angle','Emis_31','Emis_32'] 
        p_out='UIB-Imatges-MYD11A1'
        #Image offset for LST, view time and emissivity
        mult=[0.02,0.1,1,0.002,0.0005]
        offset=[0,0,-65,0.49,0]
        #Select MODIS product where QA bands is and the QA bands to be processed from the 500m product
        QA='MODIS/006/MOD11A1'
        QA_bands = ['QC_Day', 'QC_Night']
        Indices=[]
        scale=1000


    elif option ==7: #Collection LAndsat-8 OLI Tier 1
    
        #https://developers.google.com/earth-engine/datasets/catalog/LANDSAT_LC08_C01_T1_SR
        sel_col='LANDSAT/LC08/C01/T1_SR'
        #bands = ['B2','B3','B4','B5','B6','B7','pixel_qa']
        bands = ['B4','B5','pixel_qa']
        p_out='Landsat8_NDVI'
        #Image offset for LST, view time and emissivity
        mult=[0.0001,0.0001,0.0001,0.0001,0.0001,0.0001]
        offset=[0,0,0,0,0,0]
        #Select MODIS product where QA bands is and the QA bands to be processed from the 500m product
        QA=''
        QA_bands = ['pixel_qa']
        #Indices=['NDVI','EVI2','NDWI2','NDSI','Snow','Clouds']
        Indices=['NDVI']
        scale=30
        cor_rad=0.05 #this is to correct band red due to errors  in atmosferic correction. see https://labo.obs-mip.fr/multitemp/using-ndvi-with-atmospherically-corrected-data/ 

    elif option ==8: #Collection LAndsat-7 ETM+ Tier 1
    
        #https://developers.google.com/earth-engine/datasets/catalog/LANDSAT_LE07_C01_T2_SR#bands        
        sel_col='LANDSAT/LE07/C01/T1_SR'
        bands = ['B1','B2','B3','B4','B5','B7','pixel_qa'] 
        p_out='UIB-Imatges-Landsat-7-Ref'
        #Image offset for LST, view time and emissivity
        mult=[0.0001,0.0001,0.0001,0.0001,0.0001,0.0001]
        offset=[0,0,0,0,0,0]
        #Select MODIS product where QA bands is and the QA bands to be processed from the 500m product
        QA=''
        QA_bands = ['pixel_qa']
        Indices=['NDVI','EVI2','NDWI2','NDSI','Snow','Clouds']
        Indices=['NDVI','EVI2','NDWI2']
        scale=30
        cor_rad=0.05 #this is to correct band red due to errors  in atmosferic correction. see https://labo.obs-mip.fr/multitemp/using-ndvi-with-atmospherically-corrected-data/ 


    elif option ==9: #Collection LAndsat-5 TM Tier 1
    
        #https://developers.google.com/earth-engine/datasets/catalog/LANDSAT_LT05_C01_T2_SR
        sel_col='LANDSAT/LT05/C01/T1_SR'
        bands = ['B1','B2','B3','B4','B5','B7','pixel_qa'] 
        p_out='UIB-Imatges-Landsat-5-Ref'
        #Image offset for LST, view time and emissivity
        mult=[0.0001,0.0001,0.0001,0.0001,0.0001,0.0001]
        offset=[0,0,0,0,0,0]
        #Select MODIS product where QA bands is and the QA bands to be processed from the 500m product
        QA=''
        QA_bands = ['pixel_qa']
        Indices=['NDVI','EVI2','NDWI2','NDSI','Snow','Clouds']
        Indices=['NDVI','EVI2','NDWI2']
        scale=30
        cor_rad=0.05 #this is to correct band red due to errors  in atmosferic correction. see https://labo.obs-mip.fr/multitemp/using-ndvi-with-atmospherically-corrected-data/ 


    elif option ==10: #Collection Landsat-4 TM Tier 2
    
        #https://developers.google.com/earth-engine/datasets/catalog/LANDSAT_LT04_C01_T2_SR
        sel_col='LANDSAT/LT04/C01/T2_SR'
        bands = ['B1','B2','B3','B4','B5','B7','pixel_qa'] 
        p_out='UIB-Imatges-Landsat-4-Ref'
        #Image offset for LST, view time and emissivity
        mult=[0.0001,0.0001,0.0001,0.0001,0.0001,0.0001]
        offset=[0,0,0,0,0,0]
        #Select MODIS product where QA bands is and the QA bands to be processed from the 500m product
        QA=''
        QA_bands = ['pixel_qa']
        Indices=['NDVI','EVI2','NDWI2','NDSI','Snow','Clouds']
        scale=30
        cor_rad=0.05 #this is to correct band red due to errors  in atmosferic correction. see https://labo.obs-mip.fr/multitemp/using-ndvi-with-atmospherically-corrected-data/ 

    elif option ==11: #Collection LAndsat-8 OLI Tier 2
    
        #https://developers.google.com/earth-engine/datasets/catalog/LANDSAT_LC08_C01_T2_SR
        sel_col='LANDSAT/LC08/C01/T2_SR'
        bands = ['B2','B3','B4','B5','B6','B7','pixel_qa']
        #bands = ['pixel_qa']
        p_out='UIB-Imatges-Landsat-8-Ref_T2'
        #Image offset for LST, view time and emissivity
        mult=[0.0001,0.0001,0.0001,0.0001,0.0001,0.0001]
        offset=[0,0,0,0,0,0]
        #Select MODIS product where QA bands is and the QA bands to be processed from the 500m product
        QA=''
        QA_bands = ['pixel_qa']
        Indices=['NDVI','EVI2','NDWI2','NDSI','Snow','Clouds']
        scale=30
        cor_rad=0.05 #this is to correct band red due to errors  in atmosferic correction. see https://labo.obs-mip.fr/multitemp/using-ndvi-with-atmospherically-corrected-data/ 

    elif option ==12: #Collection LAndsat-7 Tier 2
    
        sel_col='LANDSAT/LE07/C01/T2_SR'
        bands = ['B2','B3','B4','B5','B6','B7','pixel_qa']
        #bands = ['pixel_qa']
        p_out='UIB-Imatges-Landsat-7-Ref_T2'
        #Image offset for LST, view time and emissivity
        mult=[0.0001,0.0001,0.0001,0.0001,0.0001,0.0001]
        offset=[0,0,0,0,0,0]
        #Select MODIS product where QA bands is and the QA bands to be processed from the 500m product
        QA=''
        QA_bands = ['pixel_qa']
        Indices=['NDVI','EVI2','NDWI2','NDSI','Snow','Clouds']
        scale=30
        cor_rad=0.05 #this is to correct band red due to errors  in atmosferic correction. see https://labo.obs-mip.fr/multitemp/using-ndvi-with-atmospherically-corrected-data/ 
        
    elif option ==13: #Collection LAndsat-5 Tier 2
    
        sel_col='LANDSAT/LT05/C01/T2_SR'
        bands = ['B2','B3','B4','B5','B6','B7','pixel_qa']
        #bands = ['pixel_qa']
        p_out='UIB-Imatges-Landsat-5-Ref_T2'
        #Image offset for LST, view time and emissivity
        mult=[0.0001,0.0001,0.0001,0.0001,0.0001,0.0001]
        offset=[0,0,0,0,0,0]
        #Select MODIS product where QA bands is and the QA bands to be processed from the 500m product
        QA=''
        QA_bands = ['pixel_qa']
        Indices=['NDVI','EVI2','NDWI2','NDSI','Snow','Clouds']
        scale=30        
        cor_rad=0.05 #this is to correct band red due to errors  in atmosferic correction. see https://labo.obs-mip.fr/multitemp/using-ndvi-with-atmospherically-corrected-data/ 
        
    #parameters are returned
    set_par = set_par_est(sel_col =sel_col, bands=bands, p_out=p_out, offset=offset, QA=QA, QA_bands=QA_bands, Indices=Indices, scale=scale, mult=mult)

    return set_par

# %%
def accumulate(image,img):
  name_image = image.get('system:index')
  image = image.select([0],[name_image])
  cumm = ee.Image(img).addBands(image)
  return cumm


def CloudMask(qa):
    
     #https://github.com/profLewis/getModisEE/blob/master/getModisEE/mapsModisEE.py
     #https://sryhandiniputeri.medium.com/the-difference-of-filtering-clouds-and-masking-cloud-in-google-earth-engine-260744bcc600
     #https://stackoverflow.com/questions/55040184/qa-with-different-bits-in-gee
     # Bits 4 is snow.
     cloudShadowBitMask=(1 << 3)
     cloudsBitMask=(1 << 5)
     
     #Get the pixel QA band.
     #Both flags should be set to 1, indicating clear conditions. 0 is clouds+clouds shadows and 1 the rest
     mask = qa.bitwiseAnd(cloudShadowBitMask).eq(0).And(qa.bitwiseAnd(cloudsBitMask).eq(0)) 
     
     
     
     #Turn mask 1- clouds+shadows and 0 -OK values
     #mask=mask.Not().multiply(-10000).add(1)
     #mask=mask.Not().multiply(-10000).add(1)

     
     #mask = getQABits(qa,4,4,'snow_detected').eq(1)

     #mask_c = getQABits(qa,5,5,'cloud')
     
     
     #mask_c_s=getQABits(qa,3,3,'cloud_shadows')


     #mask = qa.bitwiseAnd(cloudShadowBitMask).eq(0).And(qa.bitwiseAnd(cloudsBitMask).eq(0))

     #mask = qa.bitwiseAnd(cloudsBitMask).eq(0)

    

     #sombra = getQABits(qa,3,3,'cloud_shadow')
     #nubes = getQABits(qa,5,5,'cloud')
    
     #Return an image masking out cloudy areas.
     #return qa.updateMask(sombra.eq(0)).updateMask(nubes.eq(0))

    
     #mask=((mask_c.eq(0)).And(mask_c_s.eq(0)))

     #mask=(mask_c.eq(0))
     

     return mask
 
    #mask = qa.bitwiseAnd(cloudShadowBitMask).eq(0)

    #mask = qa.bitwiseAnd(cloudShadowBitMask).eq(0)

#    return image.updateMask(sombra.eq(0)).updateMask(nubes.eq(0).updateMask(cirrus_detected.eq(0))).updateMask(snow_detected.eq(0))

# %%
#en aquest mòdul eliminarem els pí­xels que tenen errors d'adquisició i aplicarem una màscara de núvols (sembla bàsicament per modis)
#https://gis.stackexchange.com/questions/308456/get-a-mask-for-modis-250m-mod09gq-using-modis-500m-mod09ga-in-google-earth
#https://gis.stackexchange.com/questions/363929/how-to-apply-a-bitmask-for-radiometric-saturation-qa-in-a-image-collection-eart

def CloudErrorsMask(QA,option,type_QA):

        #Valus is the actual image, QA_1 and QA_2 are the QA band and option depends on the product

    if option ==3:
        
        if type_QA==1:
            
            #state_1km
            #Bit 10 is the actual cloud mask    
            CloudsBitMask = 1 << 10
            #return value.updateMask(QA.bitwiseAnd(CloudsBitMask).eq(0))
            return QA.bitwiseAnd(CloudsBitMask).eq(0)

    elif option ==5: #for LST

        if type_QA==1: 
            
            #state_1km
            #Bit 10 is the actual cloud mask    
            CloudsBitMask = 2 << 0
            #return value.updateMask(QA.bitwiseAnd(CloudsBitMask).eq(0))
            #https://stackoverflow.com/questions/55040184/qa-with-different-bits-in-gee

            return QA.bitwiseAnd(3).eq(2)

            #return QA.bitwiseAnd(CloudsBitMask).eq(2)

        """
        if type_QA==2:

            #QC_500m
            # Bits 0 and 1 are give information about possible erros in bands.
            ErrorBitMask = 2 << 0

            #return value.updateMask(QA.bitwiseAnd(CloudsBitMask).eq(0))
            return QA.bitwiseAnd(CloudsBitMask).eq(0)

        """
        
        #Bit 8-9 is the cirrus mask. Values 01 and 10, thus 1 and 2, are going to be considered differently
        #for the timesat mask. Thus another code needs to be applied in the final mask
        #CirrusBitMask = 2 << 8

# %%
#Main section
if __name__ == "__main__": 
      
    
    #Select option to download and pre-process imagery. See def CollectionSelectionPar(option) function for more details
    option=7 #la 11 és de Landsat8-tier2-SR
    
    #Define specific Landsat Path and Row
    #Mallorca 196-197 ==> 32 i 33
    #Plana Lleida 198/31

    path_l=198
    row_l=31

    path_l=""
    row_l=""


    #option parameters    
    par=CollectionSelectionPar(option)
    
    #If path and row selectors activated then output folder name is changes
    if path_l!="":
    
        path_out=par.p_out+"_"+str(path_l)+"_"+str(row_l)
    
    else:
        
        path_out=par.p_out

# %%
    # https://www.usgs.gov/core-science-systems/nli/landsat/landsat-satellite-missions?qt-science_support_page_related_con=0#qt-science_support_page_related_con
    
    #Time extent
    #time=["2000-01-01","2020-12-31"]
    #time=["2000-04-30","2000-05-01"]
    #time=["2000-01-01","2020-01-01"]
    

    #Landsat-3 
    #time=["1978-03-01","1983-09-30"]

    #Landsat-2 
    #time=["1975-01-01","1983-07-30"]
    	
    #Landsat-1 
    #time=["1972-07-01","1978-01-30"]
	

    #Landsat-7 
    #time=["1999-04-01","2020-11-30"]
    #time=["2011-09-10","2020-11-30"]

    #Landsat-4 
    #time=["1982-07-01","1993-12-31"]


	 #Landsat-5 
    #time=["1984-03-01","2013-06-05"]
    #time=["2001-10-08","2013-06-05"]

    #Landsat-8 des de 2013
    #time=["2013-03-31","2020-12-31"]
    #time=["2020-11-22","2020-12-31"]


    #time=["1984-03-01","2013-06-05"]
    #time=["2001-10-08","2013-06-05"]
    #time=["2011-08-09","2013-06-05"] #Andratx
    #time=["2013-06-05","2020-12-31"] #Andratx L7
    time=["2015-01-01","2018-12-31"] #estèpiques Lleida


    #Time interval
    time_interval=1

    #compute time interval list
    t_period=ComputeProcessingPeriods(time, time_interval)
    
    #landsat = ee.ImageCollection("MODIS/006/MOD09GQ")
    
    # filter area
    #landsat_AOI = landsat.filterBounds(Mont_AOI)
# Out:
# Number of days to be processed: 1461
# Number of processing periods: 1461.0
# Time series is regular: total number of processing periods= 1461.0

# %% [markdown]
# Run the ee.Authenticate function to authenticate your access to Earth Engine servers and ee.Initialize to initialize it. Upon running the following cell you'll be asked to grant Earth Engine access to your Google account. Follow the instructions printed to the cell.

# %%
# Trigger the authentication flow.
ee.Authenticate()

# Initialize the library.
ee.Initialize()
####aquestes dues línies veien per defecte, a continuació el codi del Jordi per córrer amb python (no colab?)

#Check EE initialization
#    try:
#      ee.Initialize()
#      print('The Earth Engine package initialized successfully!')
#    except ee.EEException as e:
#      print('The Earth Engine package failed to initialize!')
#    except:
#      print("Unexpected error:", sys.exc_info()[0])
#      raise
# Out:
# To authorize access needed by Earth Engine, open the following URL in a web browser and follow the instructions. If the web browser does not start automatically, please manually browse the URL below.
#
#     https://accounts.google.com/o/oauth2/auth?client_id=517222506229-vsmmajv00ul0bs7p89v5m89qs8eb9359.apps.googleusercontent.com&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fearthengine+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdevstorage.full_control&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&response_type=code&code_challenge=kC5LYfx1H5Yja6_fevU1vkdqdkRY6gv6GIS8X6hI14A&code_challenge_method=S256
#
# The authorization workflow will generate a code, which you should paste in the box below.
# Enter verification code: 4/1AY0e-g6zPAXiCSaCXrQ29O2EejwCsagYvEdSxOQC3fHCREqJ7G9lgygQnnI
#
# Successfully saved authorization token.

# %% [markdown]
# Definir les àrees d'interès

# %%
    # setting the Area of Interest (AOI) ==> Malllorca
    #pt = ee.Geometry.Rectangle([2.22670831, 40.00861727,3.55616778, 39.23497596])
    
    #Mallorca
    #pt = ee.Geometry.Rectangle([2.22670831, 40.00861727,3.55616778, 39.23497596])

    #Montseny
    #pt = ee.Geometry.Rectangle([2.24090420, 41.86440526,2.56749104, 41.67695256])


    # setting the Area of Interest (AOI) ==> Estèpiques
pt = ee.Geometry.Rectangle([0.31, 41.34,1.43, 41.90])



region = pt.buffer(10)
    
    
    
    ###NO HABILITAT ##########
    #Mallorca
    #pt = ee.Geometry.Rectangle([434000, 4429000, 548000, 4343000])
    
    #Conca Andratx
    #pt = ee.Geometry.Rectangle([447500, 4384600, 450900, 4380500])
    
    #Montseny
    #spatial extent for exporting
    #pt = ee.Geometry.Rectangle([437000, 4635000, 464000, 4614000])
    #region_exp = pt.buffer(10)
    ###NO HABILITAT ##########



    #load Mallorca boundaries for image cliping
    #mall_mask = ee.FeatureCollection('users/jcristobalrossello/Cartografia/Mallorca_mask')
    

    #load Montseny boundaries for image masking
    #LimitsParc = ee.FeatureCollection('users/jcristobalrossello/Cartografia/LimitsParc')


    #load Montseny water bodies for image masking
    #MassesAigua = ee.FeatureCollection('users/jcristobalrossello/Cartografia/MassesAigua')


                        
    #Make an image out of the land area attribute.
   
    # Make an image out of the population attribute and display it.
    #popImage = mall_mask.filter(ee.Filter.neq('CODI', None))\
    #                     .reduceToImage(**{'properties': ['CODI'],
    #                                       'reducer': ee.Reducer.first()})


    #apply mask
    #Select the land/water mask.
    #datamask = popImage.eq(1)

    #apply mask
    #Select the land/water mask.
    #water_mask = popImage.eq(1).mask().Not()

# %%
    #Here we loop through.0 the temporal extent
for t_per in t_period:
    
        if path_l=="":
    
            col = (ee.ImageCollection(par.sel_col)
                          #.filterDate(datetime.datetime(2018, 7, 1),datetime.datetime(2018, 7, 1))
                          .filterDate(t_per[0],t_per[1])
                          .filterBounds(region)
                          .select(par.bands)
                          .sort('system:time_start')
                      )
    
        else:
    
            col = (ee.ImageCollection(par.sel_col)
                          #.filterDate(datetime.datetime(2018, 7, 1),datetime.datetime(2018, 7, 1))
                          .filterDate(t_per[0],t_per[1])
                          .filterBounds(region)
                          .select(par.bands)
                          .sort('system:time_start')
                          .filter(ee.Filter.eq('WRS_PATH', path_l))
                          .filter(ee.Filter.eq('WRS_ROW', row_l))
                          #.filterMetadata('WRS_PATH', 'equals', path_l)
                          #.filterMetadata('WRS_ROW', 'equals', row_l)
                      )
        
        #Here we check if there are images 
        if col.size().getInfo() == 0:

            print('Image not found for:',t_per[0])      


        else:    
        
            print('Processing image:',t_per[0])    
        
        
        
            if option==3 or option==4:
    
                  
                #Mask processing
                QA = (ee.ImageCollection(par.QA)
                              #.filterDate(datetime.datetime(2018, 7, 1),datetime.datetime(2018, 7, 1))
                              .filterDate(t_per[0],t_per[1])
                              .filterBounds(region)
                              .select(par.QA_bands)
                              .sort('system:time_start'))
            
            
    
                #Here the 500m product is combined to the 250 to extraxt the 500m QA bands            
                #col = ee.ImageCollection("MODIS/006/MOD09GA")
                #combined = p_500m.combine(col).filterDate(t_per[0],t_per[1])
        
                
                
                #We search day by day, so it has to be 1 image per query
                if col.size().getInfo() == 1:
            
                    date = ee.Date (col.first().get('system:time_start'))
            
                    time = date.getInfo()['value']/1000.
                    
                    #Here is the image date used as suffix    
                    suffix=dt.utcfromtimestamp(time).strftime('%Y%m%d')+'_'+str(par.scale)+'m'
        
                    bands = par.bands
    
    
                    if option==4: #clouds are only applied to the 500m product
        
                        QA_bands=par.QA_bands
                    
                        #Masks are extracted
                        for QA_band in QA_bands:
                            
                          QA_band_sel = QA.map(lambda img: img.select(QA_band)\
                                                       .set('system:time_start', img.get('system:time_start'))\
                                                       .set('system:index', img.get('system:index')))
                          #  ImageCollection to List           
                          QA_list = QA_band_sel.toList(QA_band_sel.size())
                        
                          #  Define the initial value for iterate.
                          QA_base = ee.Image(QA_list.get(0))
                          QA_base_name = QA_base.get('system:index')
                          QA_base = QA_base.select([0], [QA_base_name])
                          
                          #  Eliminate the image 'base'.
                          QA_new_col = ee.ImageCollection(QA_list.splice(0,1))
                        
                          QA_img_cummulative = ee.Image(QA_new_col.iterate(accumulate,QA_base))
        
        
                          if QA_band ==  'state_1km':
        
                            type_QA=1
        
                            CM=CloudErrorsMask(QA_img_cummulative,3,type_QA)
                    
                    
                       
                    #LST bands processing
                    for band in bands:
                     
                      col_band = col.map(lambda img: img.select(band)\
                                                   .set('system:time_start', img.get('system:time_start'))\
                                                   .set('system:index', img.get('system:index')))
                      #  ImageCollection to List           
                      col_list = col_band.toList(col_band.size())
                    
                      #  Define the initial value for iterate.
                      base = ee.Image(col_list.get(0))
                      base_name = base.get('system:index')
                      base = base.select([0], [base_name])
                      
                      #  Eliminate the image 'base'.
                      new_col = ee.ImageCollection(col_list.splice(0,1))
                      
                      """
                      if option==3:
                          
                          CM=CM.clip(region).reproject(crs='EPSG:32631', scale=par.scale)
                      """
                      #Apply error and cloud mask as well as study area mask + clip+ reprojection + offset
                      
                      
                      if option==4: #clouds are only applied to the 500m product
                          
                          img_cummulative = ee.Image(new_col.iterate(accumulate,base)).updateMask(datamask).updateMask(CM).clip(region).resample('bilinear').reproject(crs='EPSG:32631', scale=par.scale).divide(par.offset)
                      
                      else:
                       
                          img_cummulative = ee.Image(new_col.iterate(accumulate,base)).updateMask(datamask).clip(region).resample('bilinear').reproject(crs='EPSG:32631', scale=par.scale).divide(par.offset)
                      
                      
                      if band ==  'sur_refl_b01':
                          
                          #extreme values > or <0 are masked out before indices computation
                          mask_ev=ee.Image(1).where(img_cummulative.lte(0),0).where(img_cummulative.gt(1),0)
                          mask_ev=mask_ev.eq(1)
                          red=img_cummulative.updateMask(mask_ev)
                      
                      elif band ==  'sur_refl_b02':
                
                          #extreme values > or <0 are masked out before indices computation
                          mask_ev=ee.Image(1).where(img_cummulative.lte(0),0).where(img_cummulative.gt(1),0)
                          mask_ev=mask_ev.eq(1)
                          nir=img_cummulative.updateMask(mask_ev)
                          #Here we compute the vegetation indices
                    for Index in par.Indices:
    
                        if Index ==  'NDVI':
                          
                          #image = nir.subtract(red).divide(nir.add(red)).resample('bilinear').reproject(crs='EPSG:32631', scale=250).float()
                          image = nir.subtract(red).divide(nir.add(red)).float()
        
                        elif Index ==  'EVI2':
                          
                          
                          #Computed from https://www.indexdatabase.de/db/i-single.php?id=237
                          #"""EVI2 = image.expression(
                          #       '2.4 * ((NIR - RED) / (NIR + RED + 1))', {
                          #           'NIR': nir,
                          #           'RED': red,
                          #          }).reproject(crs='EPSG:32631', scale=250).select('image2')
                          #  """     
                          #A cast to float is need to save it to 32 bit
                          #image=nir.subtract(red).multiply(2.4).divide(nir.add(red).add(1)).resample('bilinear').reproject(crs='EPSG:32631', scale=250).float()
                          image=nir.subtract(red).multiply(2.4).divide(nir.add(red).add(1)).float()
                        
    
                        #Index is exported                  
                        task = ee.batch.Export.image.toDrive(
                           image = image,
                          #folder = 'UIB/Imatges/MODIS/MOD09GQ/',
                           folder = path_out,
                           fileNamePrefix = Index+'_'+suffix,
                           fileFormat = 'GeoTIFF',
                           region=region,
                           ).start()  
                      
                        print('Export Image '+ Index+ ' was submitted, please wait ...') 
                
                
            elif (option==5) or (option==6): #for LST<
                
                #Mask processing
                QA = (ee.ImageCollection(par.QA)
                              #.filterDate(datetime.datetime(2018, 7, 1),datetime.datetime(2018, 7, 1))
                              .filterDate(t_per[0],t_per[1])
                              .filterBounds(region)
                              .select(par.QA_bands)
                              .sort('system:time_start'))
                                #Here the 500m product is combined to the 250 to extraxt the 500m QA bands            
                #col = ee.ImageCollection("MODIS/006/MOD09GA")
                #combined = p_500m.combine(col).filterDate(t_per[0],t_per[1])
        
                
                
                #We search day by day, so it has to be 1 image per query
                if col.size().getInfo() == 1:
            
                    date = ee.Date (col.first().get('system:time_start'))
            
                    time = date.getInfo()['value']/1000.
                    
                    #Here is the image date used as suffix    
                    suffix=dt.utcfromtimestamp(time).strftime('%Y%m%d')+'_'+str(par.scale)+'m'
        
        
                    bands = par.bands
                    QA_bands=par.QA_bands
                
    
                    #Masks are extracted
                    for QA_band in QA_bands:
                        
                      QA_band_sel = QA.map(lambda img: img.select(QA_band)\
                                                   .set('system:time_start', img.get('system:time_start'))\
                                                   .set('system:index', img.get('system:index')))
                      #  ImageCollection to List           
                      QA_list = QA_band_sel.toList(QA_band_sel.size())
                    
                      #  Define the initial value for iterate.
                      QA_base = ee.Image(QA_list.get(0))
                      QA_base_name = QA_base.get('system:index')
                      QA_base = QA_base.select([0], [QA_base_name])
                      
                      #  Eliminate the image 'base'.
                      QA_new_col = ee.ImageCollection(QA_list.splice(0,1))
                    
                      QA_img_cummulative = ee.Image(QA_new_col.iterate(accumulate,QA_base))
    
    
                      if QA_band ==  'QC_Day':
    
                        type_QA=1
    
                        CM_day=CloudErrorsMask(QA_img_cummulative,option,type_QA)
                        
                      elif QA_band ==  'QC_Night':
    
                        type_QA=1
    
                        CM_night=CloudErrorsMask(QA_img_cummulative,option,type_QA)
                    
                       
                    #LST bands
                    for band in bands:
                     
                     
                      col_band = col.map(lambda img: img.select(band)\
                                                   .set('system:time_start', img.get('system:time_start'))\
                                                   .set('system:index', img.get('system:index')))
                      #  ImageCollection to List           
                      col_list = col_band.toList(col_band.size())
                    
                      #  Define the initial value for iterate.
                      base = ee.Image(col_list.get(0))
                      base_name = base.get('system:index')
                      base = base.select([0], [base_name])
                      
                      #  Eliminate the image 'base'.
                      new_col = ee.ImageCollection(col_list.splice(0,1))
                      
                      #A different mask is apply depending if it is night or day                     
                      if band== 'LST_Day_1km' or band== 'Day_view_time' or band== 'Day_view_angle' or band== 'Emis_31' or band== 'Emis_32':
                          
                          CM=CM_day
                          
                      elif band== 'LST_Night_1km' or band== 'Night_view_time' or band== 'Night_view_angle':   
    
                          CM=CM_night
    
    
                      #Apply error and cloud mask as well as study area mask + clip+ reprojection + offset
                      #img_cummulative = ee.Image(new_col.iterate(accumulate,base)).updateMask(datamask).updateMask(CM).clip(region).resample('bilinear').reproject(crs='EPSG:32631', scale=par.scale)
                      img_cummulative = ee.Image(new_col.iterate(accumulate,base)).updateMask(datamask).clip(region).resample('bilinear').reproject(crs='EPSG:32631', scale=par.scale)
                      
                      
                      if band ==  'LST_Day_1km' or band ==  'LST_Night_1km':
                          
                          mult=par.mult[0]
                          offset=par.offset[0]
                          
                          image=img_cummulative.multiply(mult).add(offset).float()
                      
                      elif band ==  'Day_view_time' or band ==  'Night_view_time':
    
                          mult=par.mult[1]
                          offset=par.offset[1]
    
                          image=img_cummulative.multiply(mult).add(offset).float()
                    
                      elif band ==  'Day_view_angle' or band ==  'Night_view_angle':
    
                          mult=par.mult[2]
                          offset=par.offset[2]
    
                          image=img_cummulative.multiply(mult).add(offset).float()
                    
    
                      elif band ==  'Emis_31':
                
                          mult=par.mult[3]
                          offset=par.offset[3]
                          image=img_cummulative.multiply(mult).add(offset).float()
                          emis_31=image.multiply(0.4587)
    
                      elif band ==  'Emis_32':
    
                          mult=par.mult[3]
                          offset=par.offset[3]
                          image=img_cummulative.multiply(mult).add(offset).float()
                          emis_32=image.multiply(0.5414)
    
    
                      elif band ==  'Clear_day_cov' or band ==  'Clear_night_cov':
                
                          mult=par.mult[4]
                          offset=par.offset[4]
                          image=img_cummulative.multiply(mult).add(offset).float()
    
    
    
                      #Index is exported                  
                      task = ee.batch.Export.image.toDrive(
                           image = image,
                           folder = par.p_out,
                           fileNamePrefix = band+'_'+suffix,
                           fileFormat = 'GeoTIFF',
                           region=region,
                           ).start()  
    
                      print('Export Image '+ band+ ' was submitted, please wait ...') 
    
                    #Emis_broad is computed
                    #CristÃ³bal et al. Data paper 2017
                    image= emis_31.add(emis_32).float()
                      
                    #Index is exported                  
                    task = ee.batch.Export.image.toDrive(
                         image = image,
                         folder = path_out,
                         fileNamePrefix = 'Emis_broad_'+suffix,
                         fileFormat = 'GeoTIFF',
                         region=region,
                         ).start()  
    
                    print('Export Image Emis_broad was submitted, please wait ...') 
    
    
            elif (option==7) or (option==8)or (option==9) or (option==10): #for Landsat-4 to 8
               
                
               #Multipliers and offset are the same for all Landsat optical band products
                mult=par.mult[0]
                offset=par.offset[0]
                cor_rad=par.mult[0]
                

                #Before explorting the imagery clouds, coud shadows and snow cover is maked out in addition to the Mallorca mask
                #col=col.map(maskQuality)
               
                
                #We search day by day, so it has to be 1 image per query
                if col.size().getInfo() >= 1: #more than one consecutive Landsat image from the same path but different rows. Mosaiking is needed
                    #https://developers.google.com/earth-engine/guides/ic_composite_mosaic

                    """
                    image=ee.Image(col.mosaic())
                    
                    #https://gis.stackexchange.com/questions/280156/mosaicking-a-image-collection-by-date-day-in-google-earth-engine
                    
                    #Add the mosaic to a list only if the collection has images
                    day_mosaics=ee.List(image)

                    col = ee.ImageCollection(ee.List(day_mosaics))
                    """
                    #print(col.size().getInfo())
                    
                    date_i=[t_per[0].format('YYYY-MM-DD')]    
                    
                    #Here is the image date used as suffix    
                    #suffix=dt.utcfromtimestamp(time).strftime('%Y%m%d')+'_'+str(par.scale)+'m'
                    suffix=date_i[0].replace("-","")+'_'+str(par.scale)+'m'
        
        
                    bands = par.bands
                
                    #Landsat bands
                    for band in bands:
                     
                      
                     if band != 'pixel_qa_':
                        
                          col_band = col.map(lambda img: img.select(band)\
                                                       .set('system:time_start', img.get('system:time_start'))\
                                                       .set('system:index', img.get('system:index')))
                          #ImageCollection to List           
                          col_list = col_band.toList(col_band.size())
                        
                          #  Define the initial value for iterate.
                          base = ee.Image(col_list.get(0))
                          base_name = base.get('system:index')
                          base = base.select([0], [base_name])
                          
                          #  Eliminate the image 'base'.
                          #new_col = ee.ImageCollection(col_list.splice(0,1))
                          new_col = ee.ImageCollection(col_list.splice(0,1))

                          
                          #Masks are applied and image is clipped. NODATA values as masked as -9999
                          #img_cummulative = ee.Image(new_col.iterate(accumulate,base)).updateMask(datamask).clip(region).resample('bilinear').reproject(crs='EPSG:32631', scale=par.scale).unmask(-9999)

                          #If there are more than 2 scenes in the dataset we reduce the image to one, similar to mosaic  
                          if col.size().getInfo() >1:

                              img_cummulative = ee.Image(new_col.iterate(accumulate,base)).reduce(ee.Reducer.mean())

                          else:
                               
                              img_cummulative = ee.Image(new_col.iterate(accumulate,base))
                          

                          #img_cummulative = ee.Image(new_col.iterate(accumulate,base)).clip(region).resample('bilinear').reproject(crs='EPSG:32631', scale=par.scale).unmask(-9999)
                          
                          
                          #Image selection for Landsat time series    
                          if option!=7 and band=='B4':
                              
                              nir=img_cummulative.multiply(mult).add(offset).float()
        
                          elif option!=7 and band=='B7':
        
                              swir=img_cummulative.multiply(mult).add(offset).float()
        
                          elif option!=7 and band=='B3':
                                  
                              red=img_cummulative.multiply(mult).add(offset).float()
        
                          elif option!=7 and band=='B2':
                                  
                              green=img_cummulative.multiply(mult).add(offset).float()
     
                          elif option!=7 and band=='B5':
                                  
                              swir_1=img_cummulative.multiply(mult).add(offset).float()
        
                                
                          elif option==7: #for landsat 8    
                            
                            if band=='B4': #red                       
        
                              red=img_cummulative.multiply(mult).add(offset).add(cor_rad).float()
                            
                            elif band=='B5':   #nir                     
        
                              nir=img_cummulative.multiply(mult).add(offset).float()
        
                            elif band=='B7': #swir
        
                              swir=img_cummulative.multiply(mult).add(offset).float()
        

                            elif band=='B6': #swir 1
        
                              swir_1=img_cummulative.multiply(mult).add(offset).float()

                            elif band=='B3': #green
        
                              green=img_cummulative.multiply(mult).add(offset).float()
        
                          if band != 'pixel_qa':

                              #Apply image offset for all bands                     
                              image=img_cummulative.multiply(mult).add(offset)
                              
                              #image=img_cummulative
                              
                          elif band == 'pixel_qa':

                              image=img_cummulative
                              
                              qa=img_cummulative

                          else: 
                              
                              
                              #Export snow:
                              #image=SnowMask(img_cummulative)
                              
                              #Apply image offset for all bands                     
                              #image=img_cummulative
                              image=image.updateMask(datamask).clip(region).resample('bilinear').reproject(crs='EPSG:32631', scale=par.scale).unmask(-9999)

                        #Image is exported                  
                          task = ee.batch.Export.image.toDrive(
                               image = image,
                               folder = path_out,
                               fileNamePrefix = band+'_'+suffix,
                               fileFormat = 'GeoTIFF',
                               region=region,
                               ).start()  
        
                          print('Export Image '+ band+ ' was submitted, please wait ...') 
        
                           
                    #Here we compute the vegetation indices
                    for Index in par.Indices:
    
                        if Index ==  'NDVI':
                          
                          #image = nir.subtract(red).divide(nir.add(red)).resample('bilinear').reproject(crs='EPSG:32631', scale=250).float()
                          image = nir.subtract(red).divide(nir.add(red)).float()

                        elif Index ==  'Clouds': #the cloud+cloud shadows mask is created. 1 for clouds+shadows; 0 the rest
                            
                            c_mask=CloudMask(qa)

                            #Turn mask 1- clouds+shadows and 0 -OK values
                            image=c_mask.Not()


                        else:
                            
                            print(Index+ ' not implemented yet. ...') 
                            
    
                        #Index is exported                  
                        task = ee.batch.Export.image.toDrive(
                           image = image,
                          #folder = 'UIB/Imatges/MODIS/MOD09GQ/',
                           folder = path_out,
                           fileNamePrefix = Index+'_'+suffix,
                           fileFormat = 'GeoTIFF',
                           region=region,
                           ).start()  
                      
                        print('Export Image '+ Index+ ' was submitted, please wait ...')
# Out:
# Image not found for: 2015-01-01
# Image not found for: 2015-01-02
# Image not found for: 2015-01-03
# Image not found for: 2015-01-04
# Image not found for: 2015-01-05
# Image not found for: 2015-01-06
# Processing image: 2015-01-07
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2015-01-08
# Image not found for: 2015-01-09
# Image not found for: 2015-01-10
# Image not found for: 2015-01-11
# Image not found for: 2015-01-12
# Image not found for: 2015-01-13
# Processing image: 2015-01-14
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2015-01-15
# Image not found for: 2015-01-16
# Image not found for: 2015-01-17
# Image not found for: 2015-01-18
# Image not found for: 2015-01-19
# Image not found for: 2015-01-20
# Image not found for: 2015-01-21
# Image not found for: 2015-01-22
# Image not found for: 2015-01-23
# Image not found for: 2015-01-24
# Image not found for: 2015-01-25
# Image not found for: 2015-01-26
# Image not found for: 2015-01-27
# Image not found for: 2015-01-28
# Image not found for: 2015-01-29
# Image not found for: 2015-01-30
# Image not found for: 2015-01-31
# Image not found for: 2015-02-01
# Image not found for: 2015-02-02
# Image not found for: 2015-02-03
# Image not found for: 2015-02-04
# Image not found for: 2015-02-05
# Image not found for: 2015-02-06
# Image not found for: 2015-02-07
# Processing image: 2015-02-08
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2015-02-09
# Image not found for: 2015-02-10
# Image not found for: 2015-02-11
# Image not found for: 2015-02-12
# Image not found for: 2015-02-13
# Image not found for: 2015-02-14
# Processing image: 2015-02-15
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2015-02-16
# Image not found for: 2015-02-17
# Image not found for: 2015-02-18
# Image not found for: 2015-02-19
# Image not found for: 2015-02-20
# Image not found for: 2015-02-21
# Image not found for: 2015-02-22
# Image not found for: 2015-02-23
# Processing image: 2015-02-24
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2015-02-25
# Image not found for: 2015-02-26
# Image not found for: 2015-02-27
# Image not found for: 2015-02-28
# Image not found for: 2015-03-01
# Image not found for: 2015-03-02
# Image not found for: 2015-03-03
# Image not found for: 2015-03-04
# Image not found for: 2015-03-05
# Image not found for: 2015-03-06
# Image not found for: 2015-03-07
# Image not found for: 2015-03-08
# Image not found for: 2015-03-09
# Image not found for: 2015-03-10
# Image not found for: 2015-03-11
# Processing image: 2015-03-12
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2015-03-13
# Image not found for: 2015-03-14
# Image not found for: 2015-03-15
# Image not found for: 2015-03-16
# Image not found for: 2015-03-17
# Image not found for: 2015-03-18
# Processing image: 2015-03-19
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2015-03-20
# Image not found for: 2015-03-21
# Image not found for: 2015-03-22
# Image not found for: 2015-03-23
# Image not found for: 2015-03-24
# Image not found for: 2015-03-25
# Image not found for: 2015-03-26
# Image not found for: 2015-03-27
# Processing image: 2015-03-28
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2015-03-29
# Image not found for: 2015-03-30
# Image not found for: 2015-03-31
# Image not found for: 2015-04-01
# Image not found for: 2015-04-02
# Image not found for: 2015-04-03
# Processing image: 2015-04-04
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2015-04-05
# Image not found for: 2015-04-06
# Image not found for: 2015-04-07
# Image not found for: 2015-04-08
# Image not found for: 2015-04-09
# Image not found for: 2015-04-10
# Image not found for: 2015-04-11
# Image not found for: 2015-04-12
# Processing image: 2015-04-13
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2015-04-14
# Image not found for: 2015-04-15
# Image not found for: 2015-04-16
# Image not found for: 2015-04-17
# Image not found for: 2015-04-18
# Image not found for: 2015-04-19
# Processing image: 2015-04-20
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2015-04-21
# Image not found for: 2015-04-22
# Image not found for: 2015-04-23
# Image not found for: 2015-04-24
# Image not found for: 2015-04-25
# Image not found for: 2015-04-26
# Image not found for: 2015-04-27
# Image not found for: 2015-04-28
# Processing image: 2015-04-29
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2015-04-30
# Image not found for: 2015-05-01
# Image not found for: 2015-05-02
# Image not found for: 2015-05-03
# Image not found for: 2015-05-04
# Image not found for: 2015-05-05
# Processing image: 2015-05-06
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2015-05-07
# Image not found for: 2015-05-08
# Image not found for: 2015-05-09
# Image not found for: 2015-05-10
# Image not found for: 2015-05-11
# Image not found for: 2015-05-12
# Image not found for: 2015-05-13
# Image not found for: 2015-05-14
# Processing image: 2015-05-15
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2015-05-16
# Image not found for: 2015-05-17
# Image not found for: 2015-05-18
# Image not found for: 2015-05-19
# Image not found for: 2015-05-20
# Image not found for: 2015-05-21
# Processing image: 2015-05-22
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2015-05-23
# Image not found for: 2015-05-24
# Image not found for: 2015-05-25
# Image not found for: 2015-05-26
# Image not found for: 2015-05-27
# Image not found for: 2015-05-28
# Image not found for: 2015-05-29
# Image not found for: 2015-05-30
# Processing image: 2015-05-31
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2015-06-01
# Image not found for: 2015-06-02
# Image not found for: 2015-06-03
# Image not found for: 2015-06-04
# Image not found for: 2015-06-05
# Image not found for: 2015-06-06
# Processing image: 2015-06-07
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2015-06-08
# Image not found for: 2015-06-09
# Image not found for: 2015-06-10
# Image not found for: 2015-06-11
# Image not found for: 2015-06-12
# Image not found for: 2015-06-13
# Image not found for: 2015-06-14
# Image not found for: 2015-06-15
# Processing image: 2015-06-16
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2015-06-17
# Image not found for: 2015-06-18
# Image not found for: 2015-06-19
# Image not found for: 2015-06-20
# Image not found for: 2015-06-21
# Image not found for: 2015-06-22
# Processing image: 2015-06-23
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2015-06-24
# Image not found for: 2015-06-25
# Image not found for: 2015-06-26
# Image not found for: 2015-06-27
# Image not found for: 2015-06-28
# Image not found for: 2015-06-29
# Image not found for: 2015-06-30
# Image not found for: 2015-07-01
# Processing image: 2015-07-02
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2015-07-03
# Image not found for: 2015-07-04
# Image not found for: 2015-07-05
# Image not found for: 2015-07-06
# Image not found for: 2015-07-07
# Image not found for: 2015-07-08
# Processing image: 2015-07-09
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2015-07-10
# Image not found for: 2015-07-11
# Image not found for: 2015-07-12
# Image not found for: 2015-07-13
# Image not found for: 2015-07-14
# Image not found for: 2015-07-15
# Image not found for: 2015-07-16
# Image not found for: 2015-07-17
# Processing image: 2015-07-18
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2015-07-19
# Image not found for: 2015-07-20
# Image not found for: 2015-07-21
# Image not found for: 2015-07-22
# Image not found for: 2015-07-23
# Image not found for: 2015-07-24
# Processing image: 2015-07-25
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2015-07-26
# Image not found for: 2015-07-27
# Image not found for: 2015-07-28
# Image not found for: 2015-07-29
# Image not found for: 2015-07-30
# Image not found for: 2015-07-31
# Image not found for: 2015-08-01
# Image not found for: 2015-08-02
# Processing image: 2015-08-03
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2015-08-04
# Image not found for: 2015-08-05
# Image not found for: 2015-08-06
# Image not found for: 2015-08-07
# Image not found for: 2015-08-08
# Image not found for: 2015-08-09
# Processing image: 2015-08-10
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2015-08-11
# Image not found for: 2015-08-12
# Image not found for: 2015-08-13
# Image not found for: 2015-08-14
# Image not found for: 2015-08-15
# Image not found for: 2015-08-16
# Image not found for: 2015-08-17
# Image not found for: 2015-08-18
# Processing image: 2015-08-19
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2015-08-20
# Image not found for: 2015-08-21
# Image not found for: 2015-08-22
# Image not found for: 2015-08-23
# Image not found for: 2015-08-24
# Image not found for: 2015-08-25
# Processing image: 2015-08-26
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2015-08-27
# Image not found for: 2015-08-28
# Image not found for: 2015-08-29
# Image not found for: 2015-08-30
# Image not found for: 2015-08-31
# Image not found for: 2015-09-01
# Image not found for: 2015-09-02
# Image not found for: 2015-09-03
# Image not found for: 2015-09-04
# Image not found for: 2015-09-05
# Image not found for: 2015-09-06
# Image not found for: 2015-09-07
# Image not found for: 2015-09-08
# Image not found for: 2015-09-09
# Image not found for: 2015-09-10
# Processing image: 2015-09-11
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2015-09-12
# Image not found for: 2015-09-13
# Image not found for: 2015-09-14
# Image not found for: 2015-09-15
# Image not found for: 2015-09-16
# Image not found for: 2015-09-17
# Image not found for: 2015-09-18
# Image not found for: 2015-09-19
# Processing image: 2015-09-20
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2015-09-21
# Image not found for: 2015-09-22
# Image not found for: 2015-09-23
# Image not found for: 2015-09-24
# Image not found for: 2015-09-25
# Image not found for: 2015-09-26
# Processing image: 2015-09-27
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2015-09-28
# Image not found for: 2015-09-29
# Image not found for: 2015-09-30
# Image not found for: 2015-10-01
# Image not found for: 2015-10-02
# Image not found for: 2015-10-03
# Image not found for: 2015-10-04
# Image not found for: 2015-10-05
# Processing image: 2015-10-06
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2015-10-07
# Image not found for: 2015-10-08
# Image not found for: 2015-10-09
# Image not found for: 2015-10-10
# Image not found for: 2015-10-11
# Image not found for: 2015-10-12
# Image not found for: 2015-10-13
# Image not found for: 2015-10-14
# Image not found for: 2015-10-15
# Image not found for: 2015-10-16
# Image not found for: 2015-10-17
# Image not found for: 2015-10-18
# Image not found for: 2015-10-19
# Image not found for: 2015-10-20
# Image not found for: 2015-10-21
# Processing image: 2015-10-22
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2015-10-23
# Image not found for: 2015-10-24
# Image not found for: 2015-10-25
# Image not found for: 2015-10-26
# Image not found for: 2015-10-27
# Image not found for: 2015-10-28
# Processing image: 2015-10-29
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2015-10-30
# Image not found for: 2015-10-31
# Image not found for: 2015-11-01
# Image not found for: 2015-11-02
# Image not found for: 2015-11-03
# Image not found for: 2015-11-04
# Image not found for: 2015-11-05
# Image not found for: 2015-11-06
# Processing image: 2015-11-07
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2015-11-08
# Image not found for: 2015-11-09
# Image not found for: 2015-11-10
# Image not found for: 2015-11-11
# Image not found for: 2015-11-12
# Image not found for: 2015-11-13
# Processing image: 2015-11-14
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2015-11-15
# Image not found for: 2015-11-16
# Image not found for: 2015-11-17
# Image not found for: 2015-11-18
# Image not found for: 2015-11-19
# Image not found for: 2015-11-20
# Image not found for: 2015-11-21
# Image not found for: 2015-11-22
# Processing image: 2015-11-23
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2015-11-24
# Image not found for: 2015-11-25
# Image not found for: 2015-11-26
# Image not found for: 2015-11-27
# Image not found for: 2015-11-28
# Image not found for: 2015-11-29
# Processing image: 2015-11-30
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2015-12-01
# Image not found for: 2015-12-02
# Image not found for: 2015-12-03
# Image not found for: 2015-12-04
# Image not found for: 2015-12-05
# Image not found for: 2015-12-06
# Image not found for: 2015-12-07
# Image not found for: 2015-12-08
# Processing image: 2015-12-09
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2015-12-10
# Image not found for: 2015-12-11
# Image not found for: 2015-12-12
# Image not found for: 2015-12-13
# Image not found for: 2015-12-14
# Image not found for: 2015-12-15
# Processing image: 2015-12-16
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2015-12-17
# Image not found for: 2015-12-18
# Image not found for: 2015-12-19
# Image not found for: 2015-12-20
# Image not found for: 2015-12-21
# Image not found for: 2015-12-22
# Image not found for: 2015-12-23
# Image not found for: 2015-12-24
# Processing image: 2015-12-25
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2015-12-26
# Image not found for: 2015-12-27
# Image not found for: 2015-12-28
# Image not found for: 2015-12-29
# Image not found for: 2015-12-30
# Image not found for: 2015-12-31
# Processing image: 2016-01-01
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2016-01-02
# Image not found for: 2016-01-03
# Image not found for: 2016-01-04
# Image not found for: 2016-01-05
# Image not found for: 2016-01-06
# Image not found for: 2016-01-07
# Image not found for: 2016-01-08
# Image not found for: 2016-01-09
# Processing image: 2016-01-10
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2016-01-11
# Image not found for: 2016-01-12
# Image not found for: 2016-01-13
# Image not found for: 2016-01-14
# Image not found for: 2016-01-15
# Image not found for: 2016-01-16
# Processing image: 2016-01-17
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2016-01-18
# Image not found for: 2016-01-19
# Image not found for: 2016-01-20
# Image not found for: 2016-01-21
# Image not found for: 2016-01-22
# Image not found for: 2016-01-23
# Image not found for: 2016-01-24
# Image not found for: 2016-01-25
# Processing image: 2016-01-26
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2016-01-27
# Image not found for: 2016-01-28
# Image not found for: 2016-01-29
# Image not found for: 2016-01-30
# Image not found for: 2016-01-31
# Image not found for: 2016-02-01
# Processing image: 2016-02-02
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2016-02-03
# Image not found for: 2016-02-04
# Image not found for: 2016-02-05
# Image not found for: 2016-02-06
# Image not found for: 2016-02-07
# Image not found for: 2016-02-08
# Image not found for: 2016-02-09
# Image not found for: 2016-02-10
# Image not found for: 2016-02-11
# Image not found for: 2016-02-12
# Image not found for: 2016-02-13
# Image not found for: 2016-02-14
# Image not found for: 2016-02-15
# Image not found for: 2016-02-16
# Image not found for: 2016-02-17
# Image not found for: 2016-02-18
# Image not found for: 2016-02-19
# Image not found for: 2016-02-20
# Image not found for: 2016-02-21
# Image not found for: 2016-02-22
# Image not found for: 2016-02-23
# Image not found for: 2016-02-24
# Image not found for: 2016-02-25
# Image not found for: 2016-02-26
# Processing image: 2016-02-27
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2016-02-28
# Image not found for: 2016-02-29
# Image not found for: 2016-03-01
# Image not found for: 2016-03-02
# Image not found for: 2016-03-03
# Image not found for: 2016-03-04
# Processing image: 2016-03-05
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2016-03-06
# Image not found for: 2016-03-07
# Image not found for: 2016-03-08
# Image not found for: 2016-03-09
# Image not found for: 2016-03-10
# Image not found for: 2016-03-11
# Image not found for: 2016-03-12
# Image not found for: 2016-03-13
# Processing image: 2016-03-14
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2016-03-15
# Image not found for: 2016-03-16
# Image not found for: 2016-03-17
# Image not found for: 2016-03-18
# Image not found for: 2016-03-19
# Image not found for: 2016-03-20
# Processing image: 2016-03-21
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2016-03-22
# Image not found for: 2016-03-23
# Image not found for: 2016-03-24
# Image not found for: 2016-03-25
# Image not found for: 2016-03-26
# Image not found for: 2016-03-27
# Image not found for: 2016-03-28
# Image not found for: 2016-03-29
# Processing image: 2016-03-30
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2016-03-31
# Image not found for: 2016-04-01
# Image not found for: 2016-04-02
# Image not found for: 2016-04-03
# Image not found for: 2016-04-04
# Image not found for: 2016-04-05
# Processing image: 2016-04-06
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2016-04-07
# Image not found for: 2016-04-08
# Image not found for: 2016-04-09
# Image not found for: 2016-04-10
# Image not found for: 2016-04-11
# Image not found for: 2016-04-12
# Image not found for: 2016-04-13
# Image not found for: 2016-04-14
# Processing image: 2016-04-15
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2016-04-16
# Image not found for: 2016-04-17
# Image not found for: 2016-04-18
# Image not found for: 2016-04-19
# Image not found for: 2016-04-20
# Image not found for: 2016-04-21
# Image not found for: 2016-04-22
# Image not found for: 2016-04-23
# Image not found for: 2016-04-24
# Image not found for: 2016-04-25
# Image not found for: 2016-04-26
# Image not found for: 2016-04-27
# Image not found for: 2016-04-28
# Image not found for: 2016-04-29
# Image not found for: 2016-04-30
# Processing image: 2016-05-01
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2016-05-02
# Image not found for: 2016-05-03
# Image not found for: 2016-05-04
# Image not found for: 2016-05-05
# Image not found for: 2016-05-06
# Image not found for: 2016-05-07
# Image not found for: 2016-05-08
# Image not found for: 2016-05-09
# Image not found for: 2016-05-10
# Image not found for: 2016-05-11
# Image not found for: 2016-05-12
# Image not found for: 2016-05-13
# Image not found for: 2016-05-14
# Image not found for: 2016-05-15
# Image not found for: 2016-05-16
# Processing image: 2016-05-17
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2016-05-18
# Image not found for: 2016-05-19
# Image not found for: 2016-05-20
# Image not found for: 2016-05-21
# Image not found for: 2016-05-22
# Image not found for: 2016-05-23
# Processing image: 2016-05-24
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2016-05-25
# Image not found for: 2016-05-26
# Image not found for: 2016-05-27
# Image not found for: 2016-05-28
# Image not found for: 2016-05-29
# Image not found for: 2016-05-30
# Image not found for: 2016-05-31
# Image not found for: 2016-06-01
# Processing image: 2016-06-02
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2016-06-03
# Image not found for: 2016-06-04
# Image not found for: 2016-06-05
# Image not found for: 2016-06-06
# Image not found for: 2016-06-07
# Image not found for: 2016-06-08
# Processing image: 2016-06-09
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2016-06-10
# Image not found for: 2016-06-11
# Image not found for: 2016-06-12
# Image not found for: 2016-06-13
# Image not found for: 2016-06-14
# Image not found for: 2016-06-15
# Image not found for: 2016-06-16
# Image not found for: 2016-06-17
# Processing image: 2016-06-18
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2016-06-19
# Image not found for: 2016-06-20
# Image not found for: 2016-06-21
# Image not found for: 2016-06-22
# Image not found for: 2016-06-23
# Image not found for: 2016-06-24
# Processing image: 2016-06-25
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2016-06-26
# Image not found for: 2016-06-27
# Image not found for: 2016-06-28
# Image not found for: 2016-06-29
# Image not found for: 2016-06-30
# Image not found for: 2016-07-01
# Image not found for: 2016-07-02
# Image not found for: 2016-07-03
# Processing image: 2016-07-04
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2016-07-05
# Image not found for: 2016-07-06
# Image not found for: 2016-07-07
# Image not found for: 2016-07-08
# Image not found for: 2016-07-09
# Image not found for: 2016-07-10
# Processing image: 2016-07-11
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2016-07-12
# Image not found for: 2016-07-13
# Image not found for: 2016-07-14
# Image not found for: 2016-07-15
# Image not found for: 2016-07-16
# Image not found for: 2016-07-17
# Image not found for: 2016-07-18
# Image not found for: 2016-07-19
# Processing image: 2016-07-20
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2016-07-21
# Image not found for: 2016-07-22
# Image not found for: 2016-07-23
# Image not found for: 2016-07-24
# Image not found for: 2016-07-25
# Image not found for: 2016-07-26
# Processing image: 2016-07-27
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2016-07-28
# Image not found for: 2016-07-29
# Image not found for: 2016-07-30
# Image not found for: 2016-07-31
# Image not found for: 2016-08-01
# Image not found for: 2016-08-02
# Image not found for: 2016-08-03
# Image not found for: 2016-08-04
# Processing image: 2016-08-05
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2016-08-06
# Image not found for: 2016-08-07
# Image not found for: 2016-08-08
# Image not found for: 2016-08-09
# Image not found for: 2016-08-10
# Image not found for: 2016-08-11
# Processing image: 2016-08-12
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2016-08-13
# Image not found for: 2016-08-14
# Image not found for: 2016-08-15
# Image not found for: 2016-08-16
# Image not found for: 2016-08-17
# Image not found for: 2016-08-18
# Image not found for: 2016-08-19
# Image not found for: 2016-08-20
# Processing image: 2016-08-21
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2016-08-22
# Image not found for: 2016-08-23
# Image not found for: 2016-08-24
# Image not found for: 2016-08-25
# Image not found for: 2016-08-26
# Image not found for: 2016-08-27
# Processing image: 2016-08-28
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2016-08-29
# Image not found for: 2016-08-30
# Image not found for: 2016-08-31
# Image not found for: 2016-09-01
# Image not found for: 2016-09-02
# Image not found for: 2016-09-03
# Image not found for: 2016-09-04
# Image not found for: 2016-09-05
# Processing image: 2016-09-06
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2016-09-07
# Image not found for: 2016-09-08
# Image not found for: 2016-09-09
# Image not found for: 2016-09-10
# Image not found for: 2016-09-11
# Image not found for: 2016-09-12
# Processing image: 2016-09-13
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2016-09-14
# Image not found for: 2016-09-15
# Image not found for: 2016-09-16
# Image not found for: 2016-09-17
# Image not found for: 2016-09-18
# Image not found for: 2016-09-19
# Image not found for: 2016-09-20
# Image not found for: 2016-09-21
# Processing image: 2016-09-22
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2016-09-23
# Image not found for: 2016-09-24
# Image not found for: 2016-09-25
# Image not found for: 2016-09-26
# Image not found for: 2016-09-27
# Image not found for: 2016-09-28
# Processing image: 2016-09-29
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2016-09-30
# Image not found for: 2016-10-01
# Image not found for: 2016-10-02
# Image not found for: 2016-10-03
# Image not found for: 2016-10-04
# Image not found for: 2016-10-05
# Image not found for: 2016-10-06
# Image not found for: 2016-10-07
# Processing image: 2016-10-08
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2016-10-09
# Image not found for: 2016-10-10
# Image not found for: 2016-10-11
# Image not found for: 2016-10-12
# Image not found for: 2016-10-13
# Image not found for: 2016-10-14
# Processing image: 2016-10-15
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2016-10-16
# Image not found for: 2016-10-17
# Image not found for: 2016-10-18
# Image not found for: 2016-10-19
# Image not found for: 2016-10-20
# Image not found for: 2016-10-21
# Image not found for: 2016-10-22
# Image not found for: 2016-10-23
# Processing image: 2016-10-24
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2016-10-25
# Image not found for: 2016-10-26
# Image not found for: 2016-10-27
# Image not found for: 2016-10-28
# Image not found for: 2016-10-29
# Image not found for: 2016-10-30
# Processing image: 2016-10-31
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2016-11-01
# Image not found for: 2016-11-02
# Image not found for: 2016-11-03
# Image not found for: 2016-11-04
# Image not found for: 2016-11-05
# Image not found for: 2016-11-06
# Image not found for: 2016-11-07
# Image not found for: 2016-11-08
# Processing image: 2016-11-09
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2016-11-10
# Image not found for: 2016-11-11
# Image not found for: 2016-11-12
# Image not found for: 2016-11-13
# Image not found for: 2016-11-14
# Image not found for: 2016-11-15
# Processing image: 2016-11-16
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2016-11-17
# Image not found for: 2016-11-18
# Image not found for: 2016-11-19
# Image not found for: 2016-11-20
# Image not found for: 2016-11-21
# Image not found for: 2016-11-22
# Image not found for: 2016-11-23
# Image not found for: 2016-11-24
# Processing image: 2016-11-25
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2016-11-26
# Image not found for: 2016-11-27
# Image not found for: 2016-11-28
# Image not found for: 2016-11-29
# Image not found for: 2016-11-30
# Image not found for: 2016-12-01
# Processing image: 2016-12-02
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2016-12-03
# Image not found for: 2016-12-04
# Image not found for: 2016-12-05
# Image not found for: 2016-12-06
# Image not found for: 2016-12-07
# Image not found for: 2016-12-08
# Image not found for: 2016-12-09
# Image not found for: 2016-12-10
# Processing image: 2016-12-11
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2016-12-12
# Image not found for: 2016-12-13
# Image not found for: 2016-12-14
# Image not found for: 2016-12-15
# Image not found for: 2016-12-16
# Image not found for: 2016-12-17
# Processing image: 2016-12-18
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2016-12-19
# Image not found for: 2016-12-20
# Image not found for: 2016-12-21
# Image not found for: 2016-12-22
# Image not found for: 2016-12-23
# Image not found for: 2016-12-24
# Image not found for: 2016-12-25
# Image not found for: 2016-12-26
# Processing image: 2016-12-27
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2016-12-28
# Image not found for: 2016-12-29
# Image not found for: 2016-12-30
# Image not found for: 2016-12-31
# Image not found for: 2017-01-01
# Image not found for: 2017-01-02
# Processing image: 2017-01-03
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2017-01-04
# Image not found for: 2017-01-05
# Image not found for: 2017-01-06
# Image not found for: 2017-01-07
# Image not found for: 2017-01-08
# Image not found for: 2017-01-09
# Image not found for: 2017-01-10
# Image not found for: 2017-01-11
# Processing image: 2017-01-12
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2017-01-13
# Image not found for: 2017-01-14
# Image not found for: 2017-01-15
# Image not found for: 2017-01-16
# Image not found for: 2017-01-17
# Image not found for: 2017-01-18
# Processing image: 2017-01-19
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2017-01-20
# Image not found for: 2017-01-21
# Image not found for: 2017-01-22
# Image not found for: 2017-01-23
# Image not found for: 2017-01-24
# Image not found for: 2017-01-25
# Image not found for: 2017-01-26
# Image not found for: 2017-01-27
# Processing image: 2017-01-28
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2017-01-29
# Image not found for: 2017-01-30
# Image not found for: 2017-01-31
# Image not found for: 2017-02-01
# Image not found for: 2017-02-02
# Image not found for: 2017-02-03
# Processing image: 2017-02-04
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2017-02-05
# Image not found for: 2017-02-06
# Image not found for: 2017-02-07
# Image not found for: 2017-02-08
# Image not found for: 2017-02-09
# Image not found for: 2017-02-10
# Image not found for: 2017-02-11
# Image not found for: 2017-02-12
# Image not found for: 2017-02-13
# Image not found for: 2017-02-14
# Image not found for: 2017-02-15
# Image not found for: 2017-02-16
# Image not found for: 2017-02-17
# Image not found for: 2017-02-18
# Image not found for: 2017-02-19
# Processing image: 2017-02-20
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2017-02-21
# Image not found for: 2017-02-22
# Image not found for: 2017-02-23
# Image not found for: 2017-02-24
# Image not found for: 2017-02-25
# Image not found for: 2017-02-26
# Image not found for: 2017-02-27
# Image not found for: 2017-02-28
# Processing image: 2017-03-01
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2017-03-02
# Image not found for: 2017-03-03
# Image not found for: 2017-03-04
# Image not found for: 2017-03-05
# Image not found for: 2017-03-06
# Image not found for: 2017-03-07
# Processing image: 2017-03-08
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2017-03-09
# Image not found for: 2017-03-10
# Image not found for: 2017-03-11
# Image not found for: 2017-03-12
# Image not found for: 2017-03-13
# Image not found for: 2017-03-14
# Image not found for: 2017-03-15
# Image not found for: 2017-03-16
# Processing image: 2017-03-17
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2017-03-18
# Image not found for: 2017-03-19
# Image not found for: 2017-03-20
# Image not found for: 2017-03-21
# Image not found for: 2017-03-22
# Image not found for: 2017-03-23
# Processing image: 2017-03-24
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2017-03-25
# Image not found for: 2017-03-26
# Image not found for: 2017-03-27
# Image not found for: 2017-03-28
# Image not found for: 2017-03-29
# Image not found for: 2017-03-30
# Image not found for: 2017-03-31
# Image not found for: 2017-04-01
# Processing image: 2017-04-02
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2017-04-03
# Image not found for: 2017-04-04
# Image not found for: 2017-04-05
# Image not found for: 2017-04-06
# Image not found for: 2017-04-07
# Image not found for: 2017-04-08
# Processing image: 2017-04-09
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2017-04-10
# Image not found for: 2017-04-11
# Image not found for: 2017-04-12
# Image not found for: 2017-04-13
# Image not found for: 2017-04-14
# Image not found for: 2017-04-15
# Image not found for: 2017-04-16
# Image not found for: 2017-04-17
# Processing image: 2017-04-18
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2017-04-19
# Image not found for: 2017-04-20
# Image not found for: 2017-04-21
# Image not found for: 2017-04-22
# Image not found for: 2017-04-23
# Image not found for: 2017-04-24
# Processing image: 2017-04-25
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2017-04-26
# Image not found for: 2017-04-27
# Image not found for: 2017-04-28
# Image not found for: 2017-04-29
# Image not found for: 2017-04-30
# Image not found for: 2017-05-01
# Image not found for: 2017-05-02
# Image not found for: 2017-05-03
# Processing image: 2017-05-04
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2017-05-05
# Image not found for: 2017-05-06
# Image not found for: 2017-05-07
# Image not found for: 2017-05-08
# Image not found for: 2017-05-09
# Image not found for: 2017-05-10
# Processing image: 2017-05-11
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2017-05-12
# Image not found for: 2017-05-13
# Image not found for: 2017-05-14
# Image not found for: 2017-05-15
# Image not found for: 2017-05-16
# Image not found for: 2017-05-17
# Image not found for: 2017-05-18
# Image not found for: 2017-05-19
# Processing image: 2017-05-20
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2017-05-21
# Image not found for: 2017-05-22
# Image not found for: 2017-05-23
# Image not found for: 2017-05-24
# Image not found for: 2017-05-25
# Image not found for: 2017-05-26
# Processing image: 2017-05-27
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2017-05-28
# Image not found for: 2017-05-29
# Image not found for: 2017-05-30
# Image not found for: 2017-05-31
# Image not found for: 2017-06-01
# Image not found for: 2017-06-02
# Image not found for: 2017-06-03
# Image not found for: 2017-06-04
# Processing image: 2017-06-05
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2017-06-06
# Image not found for: 2017-06-07
# Image not found for: 2017-06-08
# Image not found for: 2017-06-09
# Image not found for: 2017-06-10
# Image not found for: 2017-06-11
# Processing image: 2017-06-12
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2017-06-13
# Image not found for: 2017-06-14
# Image not found for: 2017-06-15
# Image not found for: 2017-06-16
# Image not found for: 2017-06-17
# Image not found for: 2017-06-18
# Image not found for: 2017-06-19
# Image not found for: 2017-06-20
# Processing image: 2017-06-21
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2017-06-22
# Image not found for: 2017-06-23
# Image not found for: 2017-06-24
# Image not found for: 2017-06-25
# Image not found for: 2017-06-26
# Image not found for: 2017-06-27
# Processing image: 2017-06-28
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2017-06-29
# Image not found for: 2017-06-30
# Image not found for: 2017-07-01
# Image not found for: 2017-07-02
# Image not found for: 2017-07-03
# Image not found for: 2017-07-04
# Image not found for: 2017-07-05
# Image not found for: 2017-07-06
# Processing image: 2017-07-07
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2017-07-08
# Image not found for: 2017-07-09
# Image not found for: 2017-07-10
# Image not found for: 2017-07-11
# Image not found for: 2017-07-12
# Image not found for: 2017-07-13
# Processing image: 2017-07-14
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2017-07-15
# Image not found for: 2017-07-16
# Image not found for: 2017-07-17
# Image not found for: 2017-07-18
# Image not found for: 2017-07-19
# Image not found for: 2017-07-20
# Image not found for: 2017-07-21
# Image not found for: 2017-07-22
# Processing image: 2017-07-23
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2017-07-24
# Image not found for: 2017-07-25
# Image not found for: 2017-07-26
# Image not found for: 2017-07-27
# Image not found for: 2017-07-28
# Image not found for: 2017-07-29
# Processing image: 2017-07-30
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2017-07-31
# Image not found for: 2017-08-01
# Image not found for: 2017-08-02
# Image not found for: 2017-08-03
# Image not found for: 2017-08-04
# Image not found for: 2017-08-05
# Image not found for: 2017-08-06
# Image not found for: 2017-08-07
# Processing image: 2017-08-08
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2017-08-09
# Image not found for: 2017-08-10
# Image not found for: 2017-08-11
# Image not found for: 2017-08-12
# Image not found for: 2017-08-13
# Image not found for: 2017-08-14
# Processing image: 2017-08-15
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2017-08-16
# Image not found for: 2017-08-17
# Image not found for: 2017-08-18
# Image not found for: 2017-08-19
# Image not found for: 2017-08-20
# Image not found for: 2017-08-21
# Image not found for: 2017-08-22
# Image not found for: 2017-08-23
# Processing image: 2017-08-24
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2017-08-25
# Image not found for: 2017-08-26
# Image not found for: 2017-08-27
# Image not found for: 2017-08-28
# Image not found for: 2017-08-29
# Image not found for: 2017-08-30
# Processing image: 2017-08-31
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2017-09-01
# Image not found for: 2017-09-02
# Image not found for: 2017-09-03
# Image not found for: 2017-09-04
# Image not found for: 2017-09-05
# Image not found for: 2017-09-06
# Image not found for: 2017-09-07
# Image not found for: 2017-09-08
# Image not found for: 2017-09-09
# Image not found for: 2017-09-10
# Image not found for: 2017-09-11
# Image not found for: 2017-09-12
# Image not found for: 2017-09-13
# Image not found for: 2017-09-14
# Image not found for: 2017-09-15
# Processing image: 2017-09-16
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2017-09-17
# Image not found for: 2017-09-18
# Image not found for: 2017-09-19
# Image not found for: 2017-09-20
# Image not found for: 2017-09-21
# Image not found for: 2017-09-22
# Image not found for: 2017-09-23
# Image not found for: 2017-09-24
# Processing image: 2017-09-25
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2017-09-26
# Image not found for: 2017-09-27
# Image not found for: 2017-09-28
# Image not found for: 2017-09-29
# Image not found for: 2017-09-30
# Image not found for: 2017-10-01
# Processing image: 2017-10-02
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2017-10-03
# Image not found for: 2017-10-04
# Image not found for: 2017-10-05
# Image not found for: 2017-10-06
# Image not found for: 2017-10-07
# Image not found for: 2017-10-08
# Image not found for: 2017-10-09
# Image not found for: 2017-10-10
# Processing image: 2017-10-11
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2017-10-12
# Image not found for: 2017-10-13
# Image not found for: 2017-10-14
# Image not found for: 2017-10-15
# Image not found for: 2017-10-16
# Image not found for: 2017-10-17
# Processing image: 2017-10-18
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2017-10-19
# Image not found for: 2017-10-20
# Image not found for: 2017-10-21
# Image not found for: 2017-10-22
# Image not found for: 2017-10-23
# Image not found for: 2017-10-24
# Image not found for: 2017-10-25
# Image not found for: 2017-10-26
# Processing image: 2017-10-27
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2017-10-28
# Image not found for: 2017-10-29
# Image not found for: 2017-10-30
# Image not found for: 2017-10-31
# Image not found for: 2017-11-01
# Image not found for: 2017-11-02
# Processing image: 2017-11-03
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2017-11-04
# Image not found for: 2017-11-05
# Image not found for: 2017-11-06
# Image not found for: 2017-11-07
# Image not found for: 2017-11-08
# Image not found for: 2017-11-09
# Image not found for: 2017-11-10
# Image not found for: 2017-11-11
# Processing image: 2017-11-12
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2017-11-13
# Image not found for: 2017-11-14
# Image not found for: 2017-11-15
# Image not found for: 2017-11-16
# Image not found for: 2017-11-17
# Image not found for: 2017-11-18
# Processing image: 2017-11-19
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2017-11-20
# Image not found for: 2017-11-21
# Image not found for: 2017-11-22
# Image not found for: 2017-11-23
# Image not found for: 2017-11-24
# Image not found for: 2017-11-25
# Image not found for: 2017-11-26
# Image not found for: 2017-11-27
# Processing image: 2017-11-28
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2017-11-29
# Image not found for: 2017-11-30
# Image not found for: 2017-12-01
# Image not found for: 2017-12-02
# Image not found for: 2017-12-03
# Image not found for: 2017-12-04
# Processing image: 2017-12-05
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2017-12-06
# Image not found for: 2017-12-07
# Image not found for: 2017-12-08
# Image not found for: 2017-12-09
# Image not found for: 2017-12-10
# Image not found for: 2017-12-11
# Image not found for: 2017-12-12
# Image not found for: 2017-12-13
# Processing image: 2017-12-14
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2017-12-15
# Image not found for: 2017-12-16
# Image not found for: 2017-12-17
# Image not found for: 2017-12-18
# Image not found for: 2017-12-19
# Image not found for: 2017-12-20
# Processing image: 2017-12-21
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2017-12-22
# Image not found for: 2017-12-23
# Image not found for: 2017-12-24
# Image not found for: 2017-12-25
# Image not found for: 2017-12-26
# Image not found for: 2017-12-27
# Image not found for: 2017-12-28
# Image not found for: 2017-12-29
# Processing image: 2017-12-30
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2017-12-31
# Image not found for: 2018-01-01
# Image not found for: 2018-01-02
# Image not found for: 2018-01-03
# Image not found for: 2018-01-04
# Image not found for: 2018-01-05
# Processing image: 2018-01-06
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2018-01-07
# Image not found for: 2018-01-08
# Image not found for: 2018-01-09
# Image not found for: 2018-01-10
# Image not found for: 2018-01-11
# Image not found for: 2018-01-12
# Image not found for: 2018-01-13
# Image not found for: 2018-01-14
# Processing image: 2018-01-15
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2018-01-16
# Image not found for: 2018-01-17
# Image not found for: 2018-01-18
# Image not found for: 2018-01-19
# Image not found for: 2018-01-20
# Image not found for: 2018-01-21
# Processing image: 2018-01-22
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2018-01-23
# Image not found for: 2018-01-24
# Image not found for: 2018-01-25
# Image not found for: 2018-01-26
# Image not found for: 2018-01-27
# Image not found for: 2018-01-28
# Image not found for: 2018-01-29
# Image not found for: 2018-01-30
# Processing image: 2018-01-31
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2018-02-01
# Image not found for: 2018-02-02
# Image not found for: 2018-02-03
# Image not found for: 2018-02-04
# Image not found for: 2018-02-05
# Image not found for: 2018-02-06
# Processing image: 2018-02-07
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2018-02-08
# Image not found for: 2018-02-09
# Image not found for: 2018-02-10
# Image not found for: 2018-02-11
# Image not found for: 2018-02-12
# Image not found for: 2018-02-13
# Image not found for: 2018-02-14
# Image not found for: 2018-02-15
# Processing image: 2018-02-16
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2018-02-17
# Image not found for: 2018-02-18
# Image not found for: 2018-02-19
# Image not found for: 2018-02-20
# Image not found for: 2018-02-21
# Image not found for: 2018-02-22
# Processing image: 2018-02-23
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2018-02-24
# Image not found for: 2018-02-25
# Image not found for: 2018-02-26
# Image not found for: 2018-02-27
# Image not found for: 2018-02-28
# Image not found for: 2018-03-01
# Image not found for: 2018-03-02
# Image not found for: 2018-03-03
# Processing image: 2018-03-04
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2018-03-05
# Image not found for: 2018-03-06
# Image not found for: 2018-03-07
# Image not found for: 2018-03-08
# Image not found for: 2018-03-09
# Image not found for: 2018-03-10
# Processing image: 2018-03-11
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2018-03-12
# Image not found for: 2018-03-13
# Image not found for: 2018-03-14
# Image not found for: 2018-03-15
# Image not found for: 2018-03-16
# Image not found for: 2018-03-17
# Image not found for: 2018-03-18
# Image not found for: 2018-03-19
# Processing image: 2018-03-20
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2018-03-21
# Image not found for: 2018-03-22
# Image not found for: 2018-03-23
# Image not found for: 2018-03-24
# Image not found for: 2018-03-25
# Image not found for: 2018-03-26
# Processing image: 2018-03-27
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2018-03-28
# Image not found for: 2018-03-29
# Image not found for: 2018-03-30
# Image not found for: 2018-03-31
# Image not found for: 2018-04-01
# Image not found for: 2018-04-02
# Image not found for: 2018-04-03
# Image not found for: 2018-04-04
# Processing image: 2018-04-05
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2018-04-06
# Image not found for: 2018-04-07
# Image not found for: 2018-04-08
# Image not found for: 2018-04-09
# Image not found for: 2018-04-10
# Image not found for: 2018-04-11
# Processing image: 2018-04-12
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2018-04-13
# Image not found for: 2018-04-14
# Image not found for: 2018-04-15
# Image not found for: 2018-04-16
# Image not found for: 2018-04-17
# Image not found for: 2018-04-18
# Image not found for: 2018-04-19
# Image not found for: 2018-04-20
# Processing image: 2018-04-21
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2018-04-22
# Image not found for: 2018-04-23
# Image not found for: 2018-04-24
# Image not found for: 2018-04-25
# Image not found for: 2018-04-26
# Image not found for: 2018-04-27
# Processing image: 2018-04-28
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2018-04-29
# Image not found for: 2018-04-30
# Image not found for: 2018-05-01
# Image not found for: 2018-05-02
# Image not found for: 2018-05-03
# Image not found for: 2018-05-04
# Image not found for: 2018-05-05
# Image not found for: 2018-05-06
# Processing image: 2018-05-07
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2018-05-08
# Image not found for: 2018-05-09
# Image not found for: 2018-05-10
# Image not found for: 2018-05-11
# Image not found for: 2018-05-12
# Image not found for: 2018-05-13
# Processing image: 2018-05-14
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2018-05-15
# Image not found for: 2018-05-16
# Image not found for: 2018-05-17
# Image not found for: 2018-05-18
# Image not found for: 2018-05-19
# Image not found for: 2018-05-20
# Image not found for: 2018-05-21
# Image not found for: 2018-05-22
# Processing image: 2018-05-23
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2018-05-24
# Image not found for: 2018-05-25
# Image not found for: 2018-05-26
# Image not found for: 2018-05-27
# Image not found for: 2018-05-28
# Image not found for: 2018-05-29
# Image not found for: 2018-05-30
# Image not found for: 2018-05-31
# Image not found for: 2018-06-01
# Image not found for: 2018-06-02
# Image not found for: 2018-06-03
# Image not found for: 2018-06-04
# Image not found for: 2018-06-05
# Image not found for: 2018-06-06
# Image not found for: 2018-06-07
# Processing image: 2018-06-08
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2018-06-09
# Image not found for: 2018-06-10
# Image not found for: 2018-06-11
# Image not found for: 2018-06-12
# Image not found for: 2018-06-13
# Image not found for: 2018-06-14
# Processing image: 2018-06-15
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2018-06-16
# Image not found for: 2018-06-17
# Image not found for: 2018-06-18
# Image not found for: 2018-06-19
# Image not found for: 2018-06-20
# Image not found for: 2018-06-21
# Image not found for: 2018-06-22
# Image not found for: 2018-06-23
# Processing image: 2018-06-24
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2018-06-25
# Image not found for: 2018-06-26
# Image not found for: 2018-06-27
# Image not found for: 2018-06-28
# Image not found for: 2018-06-29
# Image not found for: 2018-06-30
# Processing image: 2018-07-01
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2018-07-02
# Image not found for: 2018-07-03
# Image not found for: 2018-07-04
# Image not found for: 2018-07-05
# Image not found for: 2018-07-06
# Image not found for: 2018-07-07
# Image not found for: 2018-07-08
# Image not found for: 2018-07-09
# Processing image: 2018-07-10
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2018-07-11
# Image not found for: 2018-07-12
# Image not found for: 2018-07-13
# Image not found for: 2018-07-14
# Image not found for: 2018-07-15
# Image not found for: 2018-07-16
# Processing image: 2018-07-17
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2018-07-18
# Image not found for: 2018-07-19
# Image not found for: 2018-07-20
# Image not found for: 2018-07-21
# Image not found for: 2018-07-22
# Image not found for: 2018-07-23
# Image not found for: 2018-07-24
# Image not found for: 2018-07-25
# Processing image: 2018-07-26
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2018-07-27
# Image not found for: 2018-07-28
# Image not found for: 2018-07-29
# Image not found for: 2018-07-30
# Image not found for: 2018-07-31
# Image not found for: 2018-08-01
# Processing image: 2018-08-02
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2018-08-03
# Image not found for: 2018-08-04
# Image not found for: 2018-08-05
# Image not found for: 2018-08-06
# Image not found for: 2018-08-07
# Image not found for: 2018-08-08
# Image not found for: 2018-08-09
# Image not found for: 2018-08-10
# Processing image: 2018-08-11
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2018-08-12
# Image not found for: 2018-08-13
# Image not found for: 2018-08-14
# Image not found for: 2018-08-15
# Image not found for: 2018-08-16
# Image not found for: 2018-08-17
# Processing image: 2018-08-18
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2018-08-19
# Image not found for: 2018-08-20
# Image not found for: 2018-08-21
# Image not found for: 2018-08-22
# Image not found for: 2018-08-23
# Image not found for: 2018-08-24
# Image not found for: 2018-08-25
# Image not found for: 2018-08-26
# Processing image: 2018-08-27
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2018-08-28
# Image not found for: 2018-08-29
# Image not found for: 2018-08-30
# Image not found for: 2018-08-31
# Image not found for: 2018-09-01
# Image not found for: 2018-09-02
# Processing image: 2018-09-03
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2018-09-04
# Image not found for: 2018-09-05
# Image not found for: 2018-09-06
# Image not found for: 2018-09-07
# Image not found for: 2018-09-08
# Image not found for: 2018-09-09
# Image not found for: 2018-09-10
# Image not found for: 2018-09-11
# Processing image: 2018-09-12
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2018-09-13
# Image not found for: 2018-09-14
# Image not found for: 2018-09-15
# Image not found for: 2018-09-16
# Image not found for: 2018-09-17
# Image not found for: 2018-09-18
# Processing image: 2018-09-19
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2018-09-20
# Image not found for: 2018-09-21
# Image not found for: 2018-09-22
# Image not found for: 2018-09-23
# Image not found for: 2018-09-24
# Image not found for: 2018-09-25
# Image not found for: 2018-09-26
# Image not found for: 2018-09-27
# Processing image: 2018-09-28
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2018-09-29
# Image not found for: 2018-09-30
# Image not found for: 2018-10-01
# Image not found for: 2018-10-02
# Image not found for: 2018-10-03
# Image not found for: 2018-10-04
# Processing image: 2018-10-05
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2018-10-06
# Image not found for: 2018-10-07
# Image not found for: 2018-10-08
# Image not found for: 2018-10-09
# Image not found for: 2018-10-10
# Image not found for: 2018-10-11
# Image not found for: 2018-10-12
# Image not found for: 2018-10-13
# Processing image: 2018-10-14
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2018-10-15
# Image not found for: 2018-10-16
# Image not found for: 2018-10-17
# Image not found for: 2018-10-18
# Image not found for: 2018-10-19
# Image not found for: 2018-10-20
# Processing image: 2018-10-21
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2018-10-22
# Image not found for: 2018-10-23
# Image not found for: 2018-10-24
# Image not found for: 2018-10-25
# Image not found for: 2018-10-26
# Image not found for: 2018-10-27
# Image not found for: 2018-10-28
# Image not found for: 2018-10-29
# Processing image: 2018-10-30
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2018-10-31
# Image not found for: 2018-11-01
# Image not found for: 2018-11-02
# Image not found for: 2018-11-03
# Image not found for: 2018-11-04
# Image not found for: 2018-11-05
# Processing image: 2018-11-06
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2018-11-07
# Image not found for: 2018-11-08
# Image not found for: 2018-11-09
# Image not found for: 2018-11-10
# Image not found for: 2018-11-11
# Image not found for: 2018-11-12
# Image not found for: 2018-11-13
# Image not found for: 2018-11-14
# Image not found for: 2018-11-15
# Image not found for: 2018-11-16
# Image not found for: 2018-11-17
# Image not found for: 2018-11-18
# Image not found for: 2018-11-19
# Image not found for: 2018-11-20
# Image not found for: 2018-11-21
# Processing image: 2018-11-22
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2018-11-23
# Image not found for: 2018-11-24
# Image not found for: 2018-11-25
# Image not found for: 2018-11-26
# Image not found for: 2018-11-27
# Image not found for: 2018-11-28
# Image not found for: 2018-11-29
# Image not found for: 2018-11-30
# Processing image: 2018-12-01
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2018-12-02
# Image not found for: 2018-12-03
# Image not found for: 2018-12-04
# Image not found for: 2018-12-05
# Image not found for: 2018-12-06
# Image not found for: 2018-12-07
# Processing image: 2018-12-08
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2018-12-09
# Image not found for: 2018-12-10
# Image not found for: 2018-12-11
# Image not found for: 2018-12-12
# Image not found for: 2018-12-13
# Image not found for: 2018-12-14
# Image not found for: 2018-12-15
# Image not found for: 2018-12-16
# Processing image: 2018-12-17
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2018-12-18
# Image not found for: 2018-12-19
# Image not found for: 2018-12-20
# Image not found for: 2018-12-21
# Image not found for: 2018-12-22
# Image not found for: 2018-12-23
# Processing image: 2018-12-24
# Export Image pixel_qa was submitted, please wait ...
# Export Image NDVI was submitted, please wait ...
# Image not found for: 2018-12-25
# Image not found for: 2018-12-26
# Image not found for: 2018-12-27
# Image not found for: 2018-12-28
# Image not found for: 2018-12-29
# Image not found for: 2018-12-30
# Image not found for: 2018-12-31

# %% [markdown]
# https://gis.stackexchange.com/questions/323921/google-earth-engine-mask-application
#
#
# https://gis.stackexchange.com/questions/261495/filter-image-collection-with-a-date-list-in-google-earth-engine
#
# https://www.earthdatascience.org/courses/use-data-open-source-python/multispectral-remote-sensing/landsat-in-Python/remove-clouds-from-landsat-data/
#
#
# https://isp.uv.es/projects/cdc/GEE_cloud_detection_report.html
#
# https://www.earthdatascience.org/courses/
#
# https://www.earthdatascience.org/courses/use-data-open-source-python/multispectral-remote-sensing/landsat-in-Python/remove-clouds-from-landsat-data/
#
# https://github.com/sacridini/GEET
#
# https://medium.com/@sryhandiniputeri/the-difference-of-filtering-clouds-and-masking-cloud-in-google-earth-engine-260744bcc600
#
# Sentinel
# https://foodsecurity-tep.net/S2_NDWI
